# %%
import comet_ml
import os
COMET_API_KEY=os.getenv("cmt")

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import time
import functools
from IPython import display as Ipythondisplay
from tqdm import tqdm
from scipy.io.wavfile import write
import sys
import lab1 as lb


os.environ["cmt"] = "pgOFUjpDBgKi9t8T7Epi8VPPE"


assert torch.backends.mps.is_available(), \
       "Enable Apple GPU (MPS) or install PyTorch with MPS support"

# Comet key check
assert os.getenv("cmt"), \
       "Please insert your Comet API Key"
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 11
#       9 from scipy.io.wavfile import write
#      10 import sys
# ---> 11 import lab1 as lb
#      14 os.environ["cmt"] = "pgOFUjpDBgKi9t8T7Epi8VPPE"
#      17 assert torch.backends.mps.is_available(), \
#      18        "Enable Apple GPU (MPS) or install PyTorch with MPS support"
#
# File ~/deep_learning_MIT/Deeplearning/lab1/__init__.py:6
#       4 import urllib
#       5 import numpy as np
# ----> 6 from IPython.display import Audios
#       8 cwd=os.path.dirname(__file__)
#      10 def load_training_data():
#
# ImportError: cannot import name 'Audios' from 'IPython.display' (/Users/lalitramanmishra/deep_learning_MIT/Deeplearning/Myenv/lib/python3.11/site-packages/IPython/display.py)
