# %%
import torch
import torch.nn as nn
# Out:
# The kernel failed to start as the Python Environment 'Python 3.11.14' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
